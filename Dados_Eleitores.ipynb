# %% [markdown]
# <a href="https://colab.research.google.com/github/SergioLLima/Projeto_Analise_Dados/blob/main/Dados_Eleitores.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # DADOS POR ELEITORES

# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
from glob import glob
import numpy as np
import plotly.express as px
import plotly.graph_objects as go
import plotly.io as pio

sns.set(style='ticks')

# %%
df = pd.read_excel('eleitores-uf.xlsx')

# %% [markdown]
# ###Eleitores por Estado

# %%
df.head(n=100)
# Out:
#     nr_ano  nr_mes     nm_regiao sg_uf  qt_eleitor  qt_eleitor_biometria  \
# 0     2022       8         NORTE    AC      588433                532868
# 1     2022       8      NORDESTE    AL     2325656               2174696
# 2     2022       8         NORTE    AM     2647748               2352330
# 3     2022       8         NORTE    AP      550687                505106
# 4     2022       8      NORDESTE    BA    11291528               9962519
# 5     2022       8      NORDESTE    CE     6820673               6109475
# 6     2022       8  CENTRO-OESTE    DF     2203045               2039636
# 7     2022       8       SUDESTE    ES     2921506               1586551
# 8     2022       8  CENTRO-OESTE    GO     4870354               4511883
# 9     2022       8      NORDESTE    MA     5042999               4403758
# 10    2022       8       SUDESTE    MG    16290870               8375978
# 11    2022       8  CENTRO-OESTE    MS     1996510               1557333
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28 entries, 0 to 27
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   nr_ano                28 non-null     int64
#  1   nr_mes                28 non-null     int64
#  2   nm_regiao             28 non-null     object
#  3   sg_uf                 28 non-null     object
#  4   qt_eleitor            28 non-null     int64
#  5   qt_eleitor_biometria  28 non-null     int64
#  6   dt_carga              0 non-null      float64
# dtypes: float64(1), int64(4), object(2)
# memory usage: 1.7+ KB

# %%
df.describe().round(2)
# Out:
#        nr_ano  nr_mes   qt_eleitor  qt_eleitor_biometria  dt_carga
# count    28.0    28.0        28.00                 28.00       0.0
# mean   2022.0     8.0   5587643.25            4219707.71       NaN
# std       0.0     0.0   6960730.64            4614529.72       NaN
# min    2022.0     8.0    366240.00             129612.00       NaN
# 25%    2022.0     8.0   1915332.75            1568668.50       NaN
# 50%    2022.0     8.0   2784627.00            2394257.00       NaN
# 75%    2022.0     8.0   6870029.25            5741744.75       NaN
# max    2022.0     8.0  34667793.00           23271128.00       NaN

# %%
df.head()
# Out:
#    nr_ano  nr_mes nm_regiao sg_uf  qt_eleitor  qt_eleitor_biometria  dt_carga
# 0    2022       8     NORTE    AC      588433                532868       NaN
# 1    2022       8  NORDESTE    AL     2325656               2174696       NaN
# 2    2022       8     NORTE    AM     2647748               2352330       NaN
# 3    2022       8     NORTE    AP      550687                505106       NaN
# 4    2022       8  NORDESTE    BA    11291528               9962519       NaN

# %%
df['qt_eleitor'].describe().round(2)
# Out:
# count          28.00
# mean      5587643.25
# std       6960730.64
# min        366240.00
# 25%       1915332.75
# 50%       2784627.00
# 75%       6870029.25
# max      34667793.00
# Name: qt_eleitor, dtype: float64

# %%
df.groupby('qt_eleitor_biometria')['qt_eleitor'].median()
# Out:
# qt_eleitor_biometria
# 129612        697078.0
# 334236        366240.0
# 505106        550687.0
# 532868        588433.0
# 1016368      1094003.0
# 1127153      1230987.0
# 1557333      1996510.0
# 1572447      1671801.0
# 1586551      2921506.0
# 1890043      2469414.0
# 2039636      2203045.0
# 2174696      2325656.0
# 2352330      2647748.0
# 2383125      2554727.0
# 2405389      2573810.0
# 2894639      3091684.0
# 4235892      5489658.0
# 4403758      5042999.0
# 4511883      4870354.0
# 5383414      6082312.0
# 5619168      7018098.0
# 6109475      6820673.0
# 6678754      8593469.0
# 7265140     12827296.0
# 7833175      8475632.0
# 8375978     16290870.0
# 9962519     11291528.0
# 23271128    34667793.0
# Name: qt_eleitor, dtype: float64

# %%
df_eleitores = pd.read_excel('eleitores-região_1.xlsx')

# %% [markdown]
# ###Eleitores com Biometria

# %%
df_eleitores
# Out:
#    nr_ano  nr_mes ds_pais_uf     nm_regiao  qt_eleitor  qt_eleitor_biometria  \
# 0    2022       8     Brasil  CENTRO-OESTE    11539323               9998895
# 1    2022       8   Exterior      EXTERIOR      697078                129612
# 2    2022       8     Brasil      NORDESTE    42390976              37525216
# 3    2022       8     Brasil         NORTE    12560410              11251475
# 4    2022       8     Brasil       SUDESTE    66707465              40498797
# 5    2022       8     Brasil           SUL    22558759              18747821
#
#    dt_carga
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# 5       NaN

# %%
eleitores= pd.read_excel("eleitores-município.xlsx")
estados= pd.read_excel("eleitores-uf.xlsx")

# %%
conjuto_eleitores = pd.concat([eleitores, estados])

# %%
conjuto_eleitores
# Out:
#     nr_ano  nr_mes sg_uf nm_localidade  qt_eleitor  qt_eleitor_biometria  \
# 0     2022       8    AC         False        9529                  8871
# 1     2022       8    AC  ASSIS BRASIL        6388                  5823
# 2     2022       8    AC         False       18230                 16561
# 3     2022       8    AC        BUJARI        9941                  9285
# 4     2022       8    AC      CAPIXABA        7843                  7283
# ..     ...     ...   ...           ...         ...                   ...
# 23    2022       8    SC           NaN     5489658               4235892
# 24    2022       8    SE           NaN     1671801               1572447
# 25    2022       8    SP           NaN    34667793              23271128
# 26    2022       8    TO           NaN     1094003               1016368
# 27    2022       8    ZZ           NaN      697078                129612
#
#     dt_carga nm_regiao
# 0        NaN       NaN
# 1        NaN       NaN
# ...

# %%
df = pd.read_excel('piramide_etaria.xlsx')

# %% [markdown]
# ###Genero por Idade

# %%
df.head(n=10)
# Out:
#    nr_ano  nr_mes ds_pais_uf  cd_faixa_etaria ds_faixa_etaria    ds_sexo  \
# 0    2022       8     Brasil               -3           False   FEMININO
# 1    2022       8     Brasil               -3           False  MASCULINO
# 2    2022       8     Brasil               -3           False      False
# 3    2022       8     Brasil                1         16 anos   FEMININO
# 4    2022       8     Brasil                1         16 anos  MASCULINO
# 5    2022       8     Brasil                2         17 anos   FEMININO
# 6    2022       8     Brasil                2         17 anos  MASCULINO
# 7    2022       8     Brasil                3    18 a 20 anos   FEMININO
# 8    2022       8     Brasil                3    18 a 20 anos  MASCULINO
# 9    2022       8     Brasil                4    21 a 24 anos   FEMININO
#
#    qt_eleitor  qt_eleitor_biometria  dt_carga  sum_over_partition_1
# 0        1061                   670       NaN             156454011
# ...

# %% [markdown]
# ###Eleitores por Idade

# %%
df.groupby('ds_faixa_etaria')['qt_eleitor'].median()
# Out:
# ds_faixa_etaria
# False                       2.0
# 16 anos                181924.5
# 17 anos                297308.5
# 18 a 20 anos          1687944.5
# 21 a 24 anos          3027327.0
# 25 a 34 anos          7648454.0
# 35 a 44 anos          7734418.0
# 45 a 59 anos           123121.0
# 60 a 69 anos            38356.0
# 70 a 79 anos            11296.0
# Superior a 79 anos      12904.0
# Name: qt_eleitor, dtype: float64

# %%
plt.figure(figsize=(15,5))
sns.boxplot(x='qt_eleitor', y='ds_faixa_etaria', data=df, showfliers = False)
plt.show()

# %%
df = pd.read_excel('piramide_etaria.xlsx')

# %%
df.head()
# Out:
#    nr_ano  nr_mes ds_pais_uf  cd_faixa_etaria ds_faixa_etaria    ds_sexo  \
# 0    2022       8     Brasil               -3           False   FEMININO
# 1    2022       8     Brasil               -3           False  MASCULINO
# 2    2022       8     Brasil               -3           False      False
# 3    2022       8     Brasil                1         16 anos   FEMININO
# 4    2022       8     Brasil                1         16 anos  MASCULINO
#
#    qt_eleitor  qt_eleitor_biometria  dt_carga  sum_over_partition_1
# 0        1061                   670       NaN             156454011
# 1         925                   537       NaN             156454011
# 2           1                     0       NaN             156454011
# 3      450891                     2       NaN             156454011
# 4      363481                     5       NaN             156454011

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49 entries, 0 to 48
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   nr_ano                49 non-null     int64
#  1   nr_mes                49 non-null     int64
#  2   ds_pais_uf            49 non-null     object
#  3   cd_faixa_etaria       49 non-null     int64
#  4   ds_faixa_etaria       49 non-null     object
#  5   ds_sexo               49 non-null     object
#  6   qt_eleitor            49 non-null     int64
#  7   qt_eleitor_biometria  49 non-null     int64
#  8   dt_carga              0 non-null      float64
#  9   sum_over_partition_1  49 non-null     int64
# dtypes: float64(1), int64(6), object(3)
# memory usage: 4.0+ KB

# %%
df.describe().round(2)
# Out:
#        nr_ano  nr_mes  cd_faixa_etaria   qt_eleitor  qt_eleitor_biometria  \
# count    49.0    49.0            49.00        49.00                 49.00
# mean   2022.0     8.0             4.88   3192939.00            2411261.55
# std       0.0     0.0             3.85   5700810.91            4601928.29
# min    2022.0     8.0            -3.00         1.00                  0.00
# 25%    2022.0     8.0             2.00      6777.00                172.00
# 50%    2022.0     8.0             5.00     77983.00               2819.00
# 75%    2022.0     8.0             8.00   3658178.00            1264896.00
# max    2022.0     8.0            10.00  20083661.00           16419556.00
#
#        dt_carga  sum_over_partition_1
# count       0.0                  49.0
# mean        NaN           156454011.0
# std         NaN                   0.0
# min         NaN           156454011.0
# 25%         NaN           156454011.0
# 50%         NaN           156454011.0
# ...

# %% [markdown]
# ###Gênero Por Idade

# %%
plt.figure(figsize=(15,5))
sns.barplot(x=df['qt_eleitor'], y=df['ds_faixa_etaria'], hue=df['ds_sexo'],ci=False, estimator=np.median )
